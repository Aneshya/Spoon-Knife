# %% [markdown]
# <a href="https://colab.research.google.com/github/Aneshya/Spoon-Knife/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sample data (example research output)
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.title("Sample Research Graph")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
